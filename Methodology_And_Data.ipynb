# %% [markdown]
# # **Methodology To Be Adopted**
# ## How to gather the data and build the approach to come up with the solution

# %% [markdown]
# Now that the consultant has been identified to come up with a solution, let us check what approach he can choose -

# %% [markdown]
# Steps in building the required Data -

# %% [markdown]
# **1. Have a detailed list of Postal Codes for California State along with the Latitude and Longitude details for each and every postal code**

# %% [markdown]
# There are multiple web sites on internet where you can get the Postal Codes for California State along with Latitude and Longitude Details
# Once the website is identified, the details can be extracted in one of the two ways --
# 1. Scrape the data from the website using html5 library and load the same in pandas
# 2. Get the details downloaded in a CSV format. Make necessary changes in the data and then upload the same in the pandas

# %% [markdown]
# In case we want to scrape the data using html5 library, following command needs to be executed to install the package -
# **pip install html5lib**
#
# Once that is done - we will need lxml package to scrape the contents of the webpage - **pip install lxml**

# %% [markdown]
# Next Step -
# Import Pandas - **import pandas as pd**
#
# Using following syntax to get the details in pandas -
# dfs = pd.read_html('URL', header = 0)

# %% [markdown]
# Now, we have a data in place that will consist at least following columns -

# %% [markdown]
# 1. Postal Code
# 2. Borough
# 3. City
# 4. State
# 5. Latitude
# 6. Longitude

# %% [markdown]
# There can be few changes made like - removing the State column considering for all the columns it will be the same - **'California'**

# %% [markdown]
# **2. Considering there are multiple cities in the California State, shortlisting only Los Angeles for narrowing down the research part. Assumption is that compared to other Cities, Los Angeles is a better pick.**

# %% [markdown]
# This can be replicating the Dataframe to a new one with only the details where City is **'Los Angeles'**

# %% [markdown]
# **3. Now that we have all the Latitudes and Longitudes details for all the postal codes, next thing that we need is the neighborhood details for all these postal codes**

# %% [markdown]
# Neighborhood details actually mean Venues surrounding the Postal Code

# %% [markdown]
# We can get the details from Foursquare location data

# %% [markdown]
# Getting the Credentials First

# %% [markdown]
# CLIENT_ID = 'Foursquare ID'
# CLIENT_SECRET = 'Foursquare Secret'
# VERSION = 'Version Number'

# %% [markdown]
# Generating URL with which requests can be made to Foursquare APIs for fetching Venues data

# %% [markdown]
# url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
# CLIENT_ID, CLIENT_SECRET, VERSION, latitude, longitude, radius, limit)
# url

# %% [markdown]
# **4. Using the Foursquare Location data for getting the details about the nearby Venues**

# %% [markdown]
# We already have the Credentials in place and also the URL created.
# Now we can request Foursquare API for the venues details.

# %% [markdown]
# For that, 1st step is to import requests library using following command - **import requests**

# %% [markdown]
# Once the request is made, the result that we can from Foursquare will be a JSON file.
# To be able to read it properly and do required operations on it, we will need to get the details from JSON transferred to Pandas Dataframe.
#
# For this we will need JSON Normalization package by executing following command - **from pandas.io.json import json_normalize**

# %% [markdown]
# Making the request be using following code - **results = requests.get(url).json()**

# %% [markdown]
# **5. What to expect from Neighborhood Data and Why do we need that ?**

# %% [markdown]
# Which Neighborhoods should be more appealing for an Ice Cream Parlor ?

# %% [markdown]
# When we want our Ice Cream Parlor to be in an easy reach to the customers, first level of filtering the venues that we have will be to identify areas with a good population density.
#
# How to figure out whether the Density is low or high –
# This we can figure out based on the existing venues in the localities – The places where there are many restaurants, shopping malls, schools, colleges, universities, firms, corporate/business parks.
#
# In general, this is all about finding areas that are always filled with potential customers rather than choosing the areas which are too residential and lacks the human activity needed to sustain the business.

# %% [markdown]
# **Important venues to be tracked from the Foursquare Location Data -**

# %% [markdown]
# 1. Restaurants/Pubs
# 2. Malls
# 3. Multiplexes, Cinema Theatres, Local Operas
# 4. Schools
# 5. Universities/Colleges
# 6. Industries/Firms/Business Parks
# 7. Airports/Bus Terminals/Metro Stations
#
# Apart from these, once we have the venue details, we can add few more to the list.

# %% [markdown]
# **6. Finding Top Venues for all the Postal Codes to check the areas of our interest, the areas that will suit an Ice Cream Parlor**

# %% [markdown]
# This will be done by Finding 10 common venues in order for all the postal codes that we have. This will be done using One Hot Coding - Having a counter set for all the venues and counting the number of such venues for each of the neighbourhood.
# Once that is done, sorting it in a descending order and coming up with the Top 10 Venues for each Borough/Postal Code.
#
# Here, it is now important, to check the venues that are not of interest and removing those from the list.
#
# Now we will have a reduced list of Boroughs having the venues or localities that have interest for us.

# %% [markdown]
# **7. Using the Top Venues Data, cluster will be formed of different areas based on similarity of venues and then it will be presented to the Client - IceStorm**

# %% [markdown]
# Clusters can be formed using the similarity of the top venues for each of the Borough. Clustering can be done using K-Means.

# %% [markdown]
# This now can be mapped on a graph using the geopy plotting function

# %% [markdown]
# **8. Once we have details on the venues of the clusters, we can the prioritize the details based on the list of neighborhood in point no. 4 and come up with 2-3 Postal Codes where IceStorm can start its Ice Cream Parlor.**

# %% [markdown]
# We can then present the shortlisted clusters to the Client and then see if any further narrowing is needed and if we can get more specifications to narrow down the result.

# %%
import pandas as pd

# %%
df = pd.read_csv('California PinCodes.csv')

# %%
df.head(5)
# Out:
#    Sr. no        Borough  PinCode     District       State  Lattitude  \
# 0       1  Beverly Hills    90210  Los Angeles  California      34.09
# 1       2    Los Angeles    90002  Los Angeles  California      33.95
# 2       3    Los Angeles    90003  Los Angeles  California     33.965
# 3       4    Los Angeles    90004  Los Angeles  California     34.076
# 4       5    Los Angeles    90006  Los Angeles  California     34.049
#
#    Longitude
# 0   -118.406
# 1   -118.246
# 2   -118.273
# 3   -118.303
# 4   -118.292

# %%
df.drop(columns = 'State', inplace = True)

# %%
df
# Out:
#      Sr. no        Borough  PinCode     District  Lattitude  Longitude
# 0         1  Beverly Hills    90210  Los Angeles      34.09   -118.406
# 1         2    Los Angeles    90002  Los Angeles      33.95   -118.246
# 2         3    Los Angeles    90003  Los Angeles     33.965   -118.273
# 3         4    Los Angeles    90004  Los Angeles     34.076   -118.303
# 4         5    Los Angeles    90006  Los Angeles     34.049   -118.292
# ..      ...            ...      ...          ...        ...        ...
# 195     196      Inglewood    90311  Los Angeles     33.962   -118.353
# 196     197      Inglewood    90312  Los Angeles     33.962   -118.353
# 197     198   Santa Monica    90402  Los Angeles     34.035   -118.503
# 198     199   Santa Monica    90406  Los Angeles     34.019   -118.491
# 199     200   Santa Monica    90407  Los Angeles     34.019   -118.491
#
# [200 rows x 6 columns]

# %%
dfnew = df[df.District == 'Los Angeles']

# %%
dfnew.drop(columns = 'Sr. no', inplace = True)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dfnew.reset_index()
# Out:
#      index        Borough  PinCode     District  Lattitude  Longitude
# 0        0  Beverly Hills    90210  Los Angeles      34.09   -118.406
# 1        1    Los Angeles    90002  Los Angeles      33.95   -118.246
# 2        2    Los Angeles    90003  Los Angeles     33.965   -118.273
# 3        3    Los Angeles    90004  Los Angeles     34.076   -118.303
# 4        4    Los Angeles    90006  Los Angeles     34.049   -118.292
# ..     ...            ...      ...          ...        ...        ...
# 159    195      Inglewood    90311  Los Angeles     33.962   -118.353
# 160    196      Inglewood    90312  Los Angeles     33.962   -118.353
# 161    197   Santa Monica    90402  Los Angeles     34.035   -118.503
# 162    198   Santa Monica    90406  Los Angeles     34.019   -118.491
# 163    199   Santa Monica    90407  Los Angeles     34.019   -118.491
#
# [164 rows x 6 columns]

# %% [markdown]
# We have now narrowed down the data and have only latitudes and longitudes for Los Angeles City

# %% [markdown]
# ## Setting up the Foursquare Credentials

# %%
CLIENT_ID = 'FFC1QZGY50XQSEEWBX4EP1AWTB1XNSYKZ2GJBWPYAA2NRMQ1' # your Foursquare ID
CLIENT_SECRET = 'JX4FLWTBWZKOV1UIDS5HOY5CP1PFBJMLOHQYS4SBBSRPBLNV' # your Foursquare Secret
VERSION = '20200328'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FFC1QZGY50XQSEEWBX4EP1AWTB1XNSYKZ2GJBWPYAA2NRMQ1
# CLIENT_SECRET:JX4FLWTBWZKOV1UIDS5HOY5CP1PFBJMLOHQYS4SBBSRPBLNV

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          92 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from geopy.geocoders import Nominatim

# %%
address = 'Los Angeles, California'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Los Angeles city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Los Angeles city are 34.0536909, -118.2427666.

# %%
radius = 500
limit = 100
VERSION = 20200329
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
CLIENT_ID, CLIENT_SECRET, VERSION, latitude, longitude, radius, limit)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=FFC1QZGY50XQSEEWBX4EP1AWTB1XNSYKZ2GJBWPYAA2NRMQ1&client_secret=JX4FLWTBWZKOV1UIDS5HOY5CP1PFBJMLOHQYS4SBBSRPBLNV&v=20200329&ll=34.0536909,-118.2427666&radius=500&limit=100'

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9c912bd03993002897f518'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Civic Center',
#   'headerFullLocation': 'Civic Center, Los Angeles',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 25,
#   'suggestedBounds': {'ne': {'lat': 34.0581909045, 'lng': -118.23734531946405},
#    'sw': {'lat': 34.0491908955, 'lng': -118.24818788053594}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fecf601067d351381ea64fa',
#        'name': 'Grand Park',
#        'location': {'address': '200 N Grand Ave',
#         'crossStreet': 'btwn Temple & 1st St',
#         'lat': 34.05503441823839,
#         'lng': -118.24517873806079,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05503441823839,
#           'lng': -118.24517873806079}],
#         'distance': 268,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['200 N Grand Ave (btwn Temple & 1st St)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fecf601067d351381ea64fa-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '518471e6498e1c0b5f1401f9',
#        'name': 'Badmaash',
#        'location': {'address': '108 W 2nd St Apt 104',
#         'crossStreet': 'at Main St',
#         'lat': 34.0513423251351,
#         'lng': -118.24457108696906,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.0513423251351,
#           'lng': -118.24457108696906}],
#         'distance': 309,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['108 W 2nd St Apt 104 (at Main St)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '69218795'}},
#       'referralId': 'e-0-518471e6498e1c0b5f1401f9-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54938133498ed65f02e8c4ba',
#        'name': 'Redbird',
#        'location': {'address': '114 E 2nd St',
#         'lat': 34.050666051567845,
#         'lng': -118.24406798115865,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.050666051567845,
#           'lng': -118.24406798115865},
#          {'label': '?', 'lat': 34.050622, 'lng': -118.244067}],
#         'distance': 357,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['114 E 2nd St',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54938133498ed65f02e8c4ba-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a8e024bf964a520ba1120e3',
#        'name': 'Kinokuniya Bookstore',
#        'location': {'address': '123 Astronaut E S Onizuka St',
#         'crossStreet': 'upstairs at Weller Court Plaza',
#         'lat': 34.05014457706706,
#         'lng': -118.2422459714611,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05014457706706,
#           'lng': -118.2422459714611}],
#         'distance': 397,
#         'postalCode': '90012',
#         'cc': 'US',
#         'neighborhood': 'Little Tokyo',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['123 Astronaut E S Onizuka St (upstairs at Weller Court Plaza)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a8e024bf964a520ba1120e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51dccd46498e4f9ac4865270',
#        'name': 'JiST Cafe',
#        'location': {'address': '116 Judge John Aiso St',
#         'lat': 34.0509079511909,
#         'lng': -118.240436223769,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.0509079511909,
#           'lng': -118.240436223769}],
#         'distance': 377,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['116 Judge John Aiso St',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1097919',
#         'url': 'https://www.grubhub.com/restaurant/jist-cafe-116-judge-john-aiso-st-los-angeles/1097919?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1097919',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51dccd46498e4f9ac4865270-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a8e02c9f964a520bb1120e3',
#        'name': 'Marukai Market',
#        'location': {'address': '123 Astronaut E S Onizuka St',
#         'crossStreet': 'E 1st St',
#         'lat': 34.050049249587744,
#         'lng': -118.24214765760863,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.050049249587744,
#           'lng': -118.24214765760863}],
#         'distance': 409,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['123 Astronaut E S Onizuka St (E 1st St)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a8e02c9f964a520bb1120e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5873fafb5e789611577ee395',
#        'name': 'Birds & Bees',
#        'location': {'address': '207 S Broadway',
#         'crossStreet': 'at W 2nd St',
#         'lat': 34.05209037980495,
#         'lng': -118.24737595739992,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05209037980495,
#           'lng': -118.24737595739992}],
#         'distance': 460,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['207 S Broadway (at W 2nd St)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d4941735',
#          'name': 'Speakeasy',
#          'pluralName': 'Speakeasies',
#          'shortName': 'Speakeasy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/secretbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5873fafb5e789611577ee395-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5f9a18f964a520fcc329e3',
#        'name': 'Fugetsu-Do Sweet Shop',
#        'location': {'address': '315 E 1st St',
#         'crossStreet': 'btw San Pedro & Central',
#         'lat': 34.050195729786374,
#         'lng': -118.24048170005743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.050195729786374,
#           'lng': -118.24048170005743},
#          {'label': '?', 'lat': 34.050171, 'lng': -118.240406}],
#         'distance': 442,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['315 E 1st St (btw San Pedro & Central)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d117951735',
#          'name': 'Candy Store',
#          'pluralName': 'Candy Stores',
#          'shortName': 'Candy Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5f9a18f964a520fcc329e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b611730f964a52050092ae3',
#        'name': 'Blue Whale Bar',
#        'location': {'address': '123 Astronaut',
#         'crossStreet': 'btwn 1st & 2nd',
#         'lat': 34.04988397300476,
#         'lng': -118.2421144193744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04988397300476,
#           'lng': -118.2421144193744}],
#         'distance': 428,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['123 Astronaut (btwn 1st & 2nd)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7931735',
#          'name': 'Jazz Club',
#          'pluralName': 'Jazz Clubs',
#          'shortName': 'Jazz Club',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '93178921'}},
#       'referralId': 'e-0-4b611730f964a52050092ae3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d46f4252e326ea8ee8dfca6',
#        'name': 'LA Plaza de Cultura y Artes',
#        'location': {'address': '501 N Main St',
#         'crossStreet': 'Arcadia St',
#         'lat': 34.0567451534755,
#         'lng': -118.23998202348707,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.0567451534755,
#           'lng': -118.23998202348707}],
#         'distance': 426,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['501 N Main St (Arcadia St)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d46f4252e326ea8ee8dfca6-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5143f2d7e4b039102cf9793f',
#        'name': 'Marugame Monzo',
#        'location': {'address': '329 E 1st St',
#         'crossStreet': 'btwn San Pedro & Central Ave',
#         'lat': 34.049807074522434,
#         'lng': -118.24020195051503,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.049807074522434,
#           'lng': -118.24020195051503},
#          {'label': '?', 'lat': 34.049948, 'lng': -118.240066}],
#         'distance': 492,
#         'postalCode': '90012',
#         'cc': 'US',
#         'neighborhood': 'Little Tokyo',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['329 E 1st St (btwn San Pedro & Central Ave)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '55a59bace4b013909087cb2a',
#          'name': 'Udon Restaurant',
#          'pluralName': 'Udon Restaurants',
#          'shortName': 'Udon',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5143f2d7e4b039102cf9793f-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '40d38200f964a52047011fe3',
#        'name': 'East West Players',
#        'location': {'address': '120 Judge John Aiso St',
#         'lat': 34.05072011145923,
#         'lng': -118.23996605856985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05072011145923,
#           'lng': -118.23996605856985},
#          {'label': '?', 'lat': 34.05079, 'lng': -118.240201}],
#         'distance': 419,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['120 Judge John Aiso St',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-40d38200f964a52047011fe3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4127e200f964a520540c1fe3',
#        'name': 'Daikokuya',
#        'location': {'address': '327 E 1st St',
#         'crossStreet': 'btwn San Pedro St & Central Ave',
#         'lat': 34.049914,
#         'lng': -118.240095,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.049914,
#           'lng': -118.240095},
#          {'label': '?', 'lat': 34.049973, 'lng': -118.240102}],
#         'distance': 487,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['327 E 1st St (btwn San Pedro St & Central Ave)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '55a59bace4b013909087cb24',
#          'name': 'Ramen Restaurant',
#          'pluralName': 'Ramen Restaurants',
#          'shortName': 'Ramen',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2039974',
#         'url': 'https://www.grubhub.com/restaurant/daikokuya-little-tokyo-327-e-1st-street-los-angeles/2039974?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2039974',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4127e200f964a520540c1fe3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b87148bf964a52067af31e3',
#        'name': 'Tuesday Night Cafe',
#        'location': {'address': '120 Judge John Aiso St',
#         'crossStreet': 'at 1st St & San Pedro St',
#         'lat': 34.050900368684175,
#         'lng': -118.2402889201882,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.050900368684175,
#           'lng': -118.2402889201882}],
#         'distance': 385,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['120 Judge John Aiso St (at 1st St & San Pedro St)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b87148bf964a52067af31e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5577478b498eb83a23d81440',
#        'name': 'Señor Fish',
#        'location': {'address': '155 S Main St',
#         'crossStreet': 'Main St & 2nd St',
#         'lat': 34.051353297459706,
#         'lng': -118.24440500796936,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.051353297459706,
#           'lng': -118.24440500796936}],
#         'distance': 300,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['155 S Main St (Main St & 2nd St)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5577478b498eb83a23d81440-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb796bd1261d13ab986e798',
#        'name': 'Weller Court',
#        'location': {'address': '123 Astronaut Ellison S. Onizuka St',
#         'crossStreet': 'at E 2nd St',
#         'lat': 34.0500681044337,
#         'lng': -118.24213524575255,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.0500681044337,
#           'lng': -118.24213524575255}],
#         'distance': 407,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['123 Astronaut Ellison S. Onizuka St (at E 2nd St)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb796bd1261d13ab986e798-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5b6561f964a520b2fa28e3',
#        'name': 'Mitsuru Sushi and Grill',
#        'location': {'address': '316 E 1st St',
#         'crossStreet': 'San Pedro',
#         'lat': 34.05006621612129,
#         'lng': -118.2406199178049,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05006621612129,
#           'lng': -118.2406199178049},
#          {'label': '?', 'lat': 34.050078, 'lng': -118.240675}],
#         'distance': 449,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['316 E 1st St (San Pedro)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5b6561f964a520b2fa28e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0a9bdeffb8c9b6f0dd6b61',
#        'name': 'Chinese American Museum',
#        'location': {'address': '425 N Los Angeles St',
#         'crossStreet': 'off Arcadia St.',
#         'lat': 34.05592534005511,
#         'lng': -118.23916118547882,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05592534005511,
#           'lng': -118.23916118547882},
#          {'label': '?', 'lat': 34.055709, 'lng': -118.239048}],
#         'distance': 415,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['425 N Los Angeles St (off Arcadia St.)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '35044344'}},
#       'referralId': 'e-0-4c0a9bdeffb8c9b6f0dd6b61-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54aae895498e545686bde596',
#        'name': 'My Ramen Bar',
#        'location': {'address': '321 E 1st St',
#         'lat': 34.04999288080512,
#         'lng': -118.24034109125849,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.04999288080512,
#           'lng': -118.24034109125849},
#          {'label': '?', 'lat': 34.050081, 'lng': -118.240261}],
#         'distance': 468,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['321 E 1st St',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54aae895498e545686bde596-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6768cfaebea593ec5876d0',
#        'name': 'BOWLS LA',
#        'location': {'address': '311 E 1st St',
#         'lat': 34.05016706654175,
#         'lng': -118.24065166765695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05016706654175,
#           'lng': -118.24065166765695}],
#         'distance': 438,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['311 E 1st St',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d106951735',
#          'name': "Men's Store",
#          'pluralName': "Men's Stores",
#          'shortName': "Men's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '35225652'}},
#       'referralId': 'e-0-4c6768cfaebea593ec5876d0-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf190f925afb713310c4b6f',
#        'name': 'Go for Broke Monument',
#        'location': {'address': 'Little Tokyo',
#         'crossStreet': 'at Alameda St & Temple St',
#         'lat': 34.05114519662078,
#         'lng': -118.23904228328563,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05114519662078,
#           'lng': -118.23904228328563}],
#         'distance': 445,
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Little Tokyo (at Alameda St & Temple St)',
#          'Los Angeles, CA',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d166941735',
#          'name': 'Sculpture Garden',
#          'pluralName': 'Sculpture Gardens',
#          'shortName': 'Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf190f925afb713310c4b6f-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c50911b5ee81b8d33cacefe',
#        'name': 'Quiznos',
#        'location': {'address': '201 N Los Angeles St Ste 22',
#         'crossStreet': 'Spring',
#         'lat': 34.05442422222638,
#         'lng': -118.24074354232789,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05442422222638,
#           'lng': -118.24074354232789},
#          {'label': '?', 'lat': 34.053941, 'lng': -118.240759}],
#         'distance': 203,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['201 N Los Angeles St Ste 22 (Spring)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c50911b5ee81b8d33cacefe-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8293a3dc018cfa8eb8d06c',
#        'name': 'Fire House #1',
#        'location': {'address': '125 Paseo de La Plz Ste 400',
#         'lat': 34.05600728144978,
#         'lng': -118.23884655708467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.05600728144978,
#           'lng': -118.23884655708467}],
#         'distance': 444,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['125 Paseo de La Plz Ste 400',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8293a3dc018cfa8eb8d06c-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf5d76494b2a593ce7dacee',
#        'name': 'Pico House',
#        'location': {'address': '125 Paseo de La Plz Ste 400',
#         'lat': 34.056382974463,
#         'lng': -118.23930167144816,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.056382974463,
#           'lng': -118.23930167144816}],
#         'distance': 438,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['125 Paseo de La Plz Ste 400',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf5d76494b2a593ce7dacee-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7f94563e50b1f71594dfd3',
#        'name': 'The Cathedral Gift Shop',
#        'location': {'address': '555 W Temple St',
#         'crossStreet': 'Temple & Hill',
#         'lat': 34.057728000000004,
#         'lng': -118.245144,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.057728000000004,
#           'lng': -118.245144}],
#         'distance': 500,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['555 W Temple St (Temple & Hill)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d128951735',
#          'name': 'Gift Shop',
#          'pluralName': 'Gift Shops',
#          'shortName': 'Gift Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7f94563e50b1f71594dfd3-24'}]}]}}

# %% [markdown]
# ### Now we have all the data that can be analysed and worked upon to come up to the solution to be provided

# %% [markdown]
# ## End Of Notebook
